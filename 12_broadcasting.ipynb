# %% [markdown]
# # NumPy — Broadcasting

# %%
import numpy as np

# %%
a = np.array([1,2,3,4,5])
b = np.array([6])
print(a+b)

# %%
c = np.array([[1,2,3],[4,5,6]])
d = np.array([10,20,30])
print(c+d)
