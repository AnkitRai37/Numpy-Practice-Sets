# %% [markdown]
# # NumPy — NaN and Infinity Handling

# %%
import numpy as np

# %%
data1 = np.array([1,2, np.nan, 4, np.inf])
print(data1)

# %%
# Find NaN values
print(np.isnan(data1))

# %%
# Replace NaN/infinite values with numeric values
print(np.nan_to_num(data1))
