# %% [markdown]
# # NumPy — Array Transpose

# %%
import numpy as np

# %%
# 1D array
arr1 = np.array([1,2,3])
print(arr1)
print(arr1.T)

# %%
# 2D array
arr2 = np.array([[1,2,3],[4,5,6]])
print(arr2)
print(arr2.T)
