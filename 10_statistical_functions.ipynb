# %% [markdown]
# # NumPy — Statistical Functions

# %%
import numpy as np

# %%
a = np.array([[1,2,3],[4,5,6]])
print(a)

# %%
print(np.sum(a))
print(np.mean(a))
print(np.median(a))
print(np.std(a))
print(np.min(a))
print(np.max(a))
